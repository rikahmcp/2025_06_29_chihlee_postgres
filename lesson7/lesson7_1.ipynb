# %% [markdown]
# ### 這是python基礎課程
# - python基本資料型別

# %%
print("Hello! Python!")
print("以下是python的基本資料類型(int,float,str,bool)")
print(15) #整數,(int)
print(15.0) #浮點數,(float)
print("15.0") #字串,(str)
print('15.0') #字串,(str)
print(True) #布林值,(bool)
print(False) #布林值,(bool)
# Out:
# Hello! Python!
# 以下是python的基本資料類型(int,float,str,bool)
# False

# %%
print("SELECT \"stationCode\",\"stationName\",\"stationAddrTw\"\nFROM \"台鐵車站資訊\"\nWHERE \"stationAddrTw\" LIKE \'%基隆市%\';")
# Out:
# SELECT "stationCode","stationName","stationAddrTw"
# FROM "台鐵車站資訊"
# WHERE "stationAddrTw" LIKE '%基隆市%';

# %%
"單行字串"
'單行字串'
# Out:
# '單行字串'

# %%
#多行字串
print("""SELECT "stationCode","stationName","stationAddrTw"
FROM "台鐵車站資訊"
WHERE "stationAddrTw" LIKE '%基隆市%';""")
# Out:
# SELECT "stationCode","stationName","stationAddrTw"
# FROM "台鐵車站資訊"
# WHERE "stationAddrTw" LIKE '%基隆市%';

# %%
print("""CREATE TABLE 台鐵車站資訊 (
	"stationCode" int4 NOT NULL,
	"stationName" varchar(50) NULL,
	"name" varchar(50) NULL,
	"stationAddrTw" varchar(50) NULL,
	"stationTel" varchar(50) NULL,
	gps varchar(50) NULL,
	"haveBike" varchar(50) NULL,
	CONSTRAINT 台鐵車站資訊_pkey PRIMARY KEY ("stationCode")
);""")
# Out:
# CREATE TABLE 台鐵車站資訊 (
# 	"stationCode" int4 NOT NULL,
# 	"stationName" varchar(50) NULL,
# 	"name" varchar(50) NULL,
# 	"stationAddrTw" varchar(50) NULL,
# 	"stationTel" varchar(50) NULL,
# 	gps varchar(50) NULL,
# 	"haveBike" varchar(50) NULL,
# 	CONSTRAINT 台鐵車站資訊_pkey PRIMARY KEY ("stationCode")
# );

# %%
print("""SELECT
  "stationCode",
  "stationName",
  "name"
FROM
  "台鐵車站資訊"
WHERE
  "stationAddrTw" LIKE '基隆市%';""")
# Out:
# SELECT
#   "stationCode",
#   "stationName",
#   "name"
# FROM
#   "台鐵車站資訊"
# WHERE
#   "stationAddrTw" LIKE '基隆市%';

# %%
print("""
/*取出基隆市的車站資訊*/
SELECT
  "stationCode",
  "stationName",
  "name"
FROM
  "台鐵車站資訊"
WHERE
  "stationAddrTw" LIKE '基隆市%';

/*取出臺北市的車站資訊*/
SELECT
  "stationCode",
  "stationName",
  "name"
FROM
  "台鐵車站資訊"
WHERE
  "stationAddrTw" LIKE '臺北市%';

/*取出基隆市有那些火車站*/
SELECT *
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode";

/*取出基隆火車站2022年3月1日資料*/
SELECT *
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 日期 = '2022-03-01' AND "stationName" = '基隆';


/*取出基隆火車站2022年3月份資料,時間由小到大排序*/
SELECT *
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE (日期 BETWEEN '2022-03-01'AND '2022-03-31') AND "stationName" = '基隆'
ORDER BY "日期" ASC;

/*取出基隆火車站和臺北火車站2022年3月份資料,時間由小到大排序*/
SELECT *
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE (日期 BETWEEN '2022-03-01'AND '2022-03-31') AND "stationName" IN ('基隆','臺北')
ORDER BY "日期" ASC;

/*取出資料進站人數最多的前10筆資料*/
SELECT *
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
ORDER BY 進站人數 DESC
LIMIT 10

/*全省各站點2022年進站總人數*/
SELECT DATE_PART('year',日期) AS 年份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 日期 BETWEEN '2022-01-01' AND '2022-12-31'
GROUP BY 年份,名稱
ORDER BY 進站人數 DESC;

/*全省各站點2022年進站總人數大於5佰萬人的站點*/
SELECT DATE_PART('year',日期) AS 年份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 日期 BETWEEN '2022-01-01' AND '2022-12-31'
GROUP BY 年份,名稱
HAVING SUM(進站人數) > 5000000
ORDER BY 進站人數 DESC;

/*基隆火車站2020年,每月份進站人數*/
SELECT DATE_TRUNC('month',日期) AS 月份,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" = '基隆' AND 日期 BETWEEN '2020-01-01' AND '2020-12-31'
GROUP BY 月份
ORDER BY 進站人數;

/*基隆火車站2020年,每月份進站人數,由多至少*/
SELECT DATE_PART('month',日期) AS 月份,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" = '基隆' AND 日期 BETWEEN '2020-01-01' AND '2020-12-31'
GROUP BY 月份
ORDER BY 進站人數 DESC;

/*基隆火車站2020,2021,2022,每年進站人數*/
SELECT DATE_PART('year',日期) AS 年份,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" = '基隆' AND 日期 BETWEEN '2020-01-01' AND '2022-12-31'
GROUP BY 年份
ORDER BY 進站人數 DESC;

/*基隆火車站,臺北火車站2020,2021,2022,每年進站人數*/
SELECT DATE_PART('year',日期) AS 年份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" IN ('基隆','臺北') AND 日期 BETWEEN '2020-01-01' AND '2022-12-31'
GROUP BY 年份,名稱
ORDER BY 進站人數 DESC;

/*練習 1： 查詢 2021 年全省各站點進站總人數，並按進站人數由高至低排序*/
SELECT DATE_PART('year',日期) AS 年份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 日期 BETWEEN '2021-01-01' AND '2021-12-31'
GROUP BY 年份,名稱
ORDER BY 進站人數 DESC;

/*練習 2： 查詢 2022 年進站人數超過 1000 萬人的站點*/
SELECT DATE_PART('year',日期) AS 年份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 日期 BETWEEN '2022-01-01' AND '2022-12-31'
GROUP BY 年份,名稱
HAVING SUM(進站人數) > 10000000
ORDER BY 進站人數 DESC;

/*練習 3： 查詢臺中火車站 2020-2022 年每年的進站人數*/
SELECT DATE_PART('year',日期) AS 年份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" = '臺中' AND 日期 BETWEEN '2020-01-01' AND '2022-12-31'
GROUP BY 年份,名稱;

/*練習 4： 查詢高雄火車站 2021 年每月份的進站人數，並按月份排序*/
SELECT DATE_PART('month',日期) AS 月份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" = '高雄' AND 日期 BETWEEN '2021-01-01' AND '2021-12-31'
GROUP BY 月份,名稱
ORDER BY 月份 ASC;

/*練習 5： 查詢 2020 年進站人數前 10 名的站點*/
SELECT DATE_PART('year',日期) AS 年份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 日期 BETWEEN '2021-01-01' AND '2021-12-31'
GROUP BY 年份,名稱
ORDER BY 進站人數 DESC
LIMIT 10;

/*練習 6： 查詢台北、桃園、新竹三個火車站 2022 年的進站總人數，並按站點名稱排序*/
SELECT "stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" IN ('臺北','桃園','新竹') AND 日期 BETWEEN '2022-01-01' AND '2022-12-31'
GROUP BY 名稱
ORDER BY 名稱 ASC;

/*練習 7： 查詢 2021 年每月份全省進站總人數，並找出進站人數超過 5000 萬人的月份*/
SELECT DATE_PART('month',日期) AS 月份,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 日期 BETWEEN '2021-01-01' AND '2021-12-31'
GROUP BY 月份
HAVING SUM(進站人數) > 5000000;

/*練習 8： 查詢嘉義火車站 2020 年第一季（1-3月）每月的進站人數*/
SELECT DATE_PART('month',日期) AS 月份,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" = '嘉義' AND 日期 BETWEEN '2020-01-01' AND '2020-3-31'
GROUP BY 月份
ORDER BY 月份 ASC;

/*練習 9： 查詢 2022 年平均每日進站人數超過 2 萬人的站點*/
SELECT "stationName" AS 名稱,AVG(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 日期 BETWEEN '2022-01-01' AND '2022-12-31'
GROUP BY 名稱
HAVING AVG(進站人數) > 20000;

/*練習 10： 查詢台南、高雄兩個火車站 2020-2022 年每年進站人數的比較，並計算兩站每年的人數差距*/
SELECT DATE_PART('year',日期) AS 年份,"stationName" AS 名稱,SUM(進站人數) AS 進站人數
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE "stationName" IN ('臺南','高雄') AND 日期 BETWEEN '2020-01-01' AND '2022-12-31'
GROUP BY 年份,名稱
ORDER BY 年份,名稱;

/*進站人數最多的一筆*/
SELECT *
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE 進站人數=(SELECT MAX(進站人數)
                FROM "每日各站進出站人數");

/*各站點進站人數最多的一筆*/
SELECT *
FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
WHERE (車站代碼,進站人數) IN (
    SELECT 車站代碼,MAX(進站人數)
    FROM "每日各站進出站人數"
    GROUP BY 車站代碼
)
ORDER BY 車站代碼 ASC;
""")
# Out:
# /*取出基隆市的車站資訊*/
# SELECT
#   "stationCode",
#   "stationName",
#   "name"
# FROM
#   "台鐵車站資訊"
# WHERE
#   "stationAddrTw" LIKE '基隆市%';
#
# /*取出臺北市的車站資訊*/
# SELECT
#   "stationCode",
#   "stationName",
#   "name"
# FROM
#   "台鐵車站資訊"
# WHERE
#   "stationAddrTw" LIKE '臺北市%';
#
# /*取出基隆市有那些火車站*/
# SELECT *
# FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode";
#
# /*取出基隆火車站2022年3月1日資料*/
# SELECT *
# FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
# WHERE 日期 = '2022-03-01' AND "stationName" = '基隆';
#
#
# /*取出基隆火車站2022年3月份資料,時間由小到大排序*/
# SELECT *
# FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
# WHERE (日期 BETWEEN '2022-03-01'AND '2022-03-31') AND "stationName" = '基隆'
# ORDER BY "日期" ASC;
#
# /*取出基隆火車站和臺北火車站2022年3月份資料,時間由小到大排序*/
# SELECT *
# FROM "每日各站進出站人數" LEFT JOIN "台鐵車站資訊" ON "車站代碼" = "stationCode"
# WHERE (日期 BETWEEN '2022-03-01'AND '2022-03-31') AND "stationName" IN ('基隆','臺北')
# ORDER BY "日期" ASC;
#
# /*取出資料進站人數最多的前10筆資料*/
# SELECT *
# ...
